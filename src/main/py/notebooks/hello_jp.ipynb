# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("pyspark-nb").master("local").getOrCreate()
text = spark.read.text("/Users/shad/hello.in")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/shad/experiments/spark-samples/src/main/py/notebooks/hello_jp.ipynb Cell 1' in <module>
# ----> <a href='vscode-notebook-cell:/Users/shad/experiments/spark-samples/src/main/py/notebooks/hello_jp.ipynb#ch0000000?line=0'>1</a> from pyspark.sql import SparkSession
#       <a href='vscode-notebook-cell:/Users/shad/experiments/spark-samples/src/main/py/notebooks/hello_jp.ipynb#ch0000000?line=1'>2</a> spark = SparkSession.builder.appName("pyspark-nb").master("local").getOrCreate()
#       <a href='vscode-notebook-cell:/Users/shad/experiments/spark-samples/src/main/py/notebooks/hello_jp.ipynb#ch0000000?line=2'>3</a> text = spark.read.text("/Users/shad/hello.in")
#
# File ~/experiments/spark-samples/venv/lib/python3.9/site-packages/pyspark/__init__.py:51, in <module>
# ...

# %%
text.show(10)
